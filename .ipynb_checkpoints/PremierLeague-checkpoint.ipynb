# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
pos = pd.read_csv("playerStats.csv")

# %%
pos
# Out:
#                         Team  JerseyNo           Player             Position  \
# 0                    Arsenal         7      Bukayo Saka  Defender/Midfielder
# 1                    Arsenal         6          Gabriel             Defender
# 2                    Arsenal        32   Aaron Ramsdale           Goalkeeper
# 3                    Arsenal         4        Ben White             Defender
# 4                    Arsenal         8  Martin Odegaard           Midfielder
# ..                       ...       ...              ...                  ...
# 618  Wolverhampton Wanderers        21       John Ruddy           Goalkeeper
# 619  Wolverhampton Wanderers        27     Romain Saïss  Defender/Midfielder
# 620  Wolverhampton Wanderers        24       Tote Gomes             Defender
# 621  Wolverhampton Wanderers        37     Adama Traoré   Midfielder/Forward
# 622  Wolverhampton Wanderers        11          Trincão   Midfielder/Forward
#
# ...

# %%
pos = pos[["Player", "Position", "Apearances", "Substitutions", "Goals", "Penalties"]]

# %%
pos
# Out:
#               Player             Position  Apearances  Substitutions  Goals  \
# 0        Bukayo Saka  Defender/Midfielder          40              3     12
# 1            Gabriel             Defender          37              1      5
# 2     Aaron Ramsdale           Goalkeeper          37              0      0
# 3          Ben White             Defender          37              0      0
# 4    Martin Odegaard           Midfielder          36              4      7
# ..               ...                  ...         ...            ...    ...
# 618       John Ruddy           Goalkeeper           5              1      0
# 619     Romain Saïss  Defender/Midfielder          32              0      3
# 620       Tote Gomes             Defender           5              0      0
# 621     Adama Traoré   Midfielder/Forward          11             12      1
# 622          Trincão   Midfielder/Forward          16             14      3
#
#      Penalties
# 0            2
# 1            0
# ...

# %%
topScorers = pd.read_csv("topScorers.csv")

# %%
topScorers
# Out:
#        №              Player                     Team  Apps   Min   G   A  \
# 0      1       Son Heung-Min                Tottenham    35  3051  23   7
# 1      2       Mohamed Salah                Liverpool    35  2757  23  13
# 2      3   Cristiano Ronaldo        Manchester United    30  2468  18   3
# 3      4          Harry Kane                Tottenham    37  3229  17   9
# 4      5          Sadio Mané                Liverpool    34  2833  16   2
# ..   ...                 ...                      ...   ...   ...  ..  ..
# 532  533           Chiquinho  Wolverhampton Wanderers     8   191   0   3
# 533  534        Josh Dasilva                Brentford     9   242   0   0
# 534  535     Daniel Chesters                 West Ham     1     1   0   0
# 535  536      Tony Springett                  Norwich     3   138   0   0
# 536  537  Alejandro Garnacho        Manchester United     2    11   0   0
#
#              xG         xA  xG90  xA90
# 0    16.99-6.01  7.85+0.85  0.50  0.23
# ...

# %%
del topScorers["№"]

# %%
topScorers.groupby(["Player", "G"])

# %%
# combining the csvs once cleaned and checked
combined = topScorers.merge(topScorers, how="outer", on=["Player", "G"])

# %%
combined.head(5)
